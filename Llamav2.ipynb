# %% [markdown]
# <a href="https://colab.research.google.com/github/Zine-Elabidine/RAG-with-Llama-v2/blob/main/Llamav2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install -qU transformers accelerate einops langchain xformers bitsandbytes faiss-gpu sentence_transformers pypdf

# %% [markdown]
# ### Llama v2 7b

# %%
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-7b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, you need an access token
hf_auth = '*********************'
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)

# enable evaluation mode to allow model inference
model.eval()

print(f"Model loaded on {device}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py:1067: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Model loaded on cuda:0

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:690: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
stop_list = ['\nHuman:', '\n```\n']

stop_token_ids = [tokenizer(x)['input_ids'] for x in stop_list]
stop_token_ids
# Out:
# [[1, 29871, 13, 29950, 7889, 29901], [1, 29871, 13, 28956, 13]]

# %%
import torch

stop_token_ids = [torch.LongTensor(x).to(device) for x in stop_token_ids]
stop_token_ids
# Out:
# [tensor([    1, 29871,    13, 29950,  7889, 29901], device='cuda:0'),
#  tensor([    1, 29871,    13, 28956,    13], device='cuda:0')]

# %%
from transformers import StoppingCriteria, StoppingCriteriaList

# define custom stopping criteria object
class StopOnTokens(StoppingCriteria):
    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        for stop_ids in stop_token_ids:
            if torch.eq(input_ids[0][-len(stop_ids):], stop_ids).all():
                return True
        return False

stopping_criteria = StoppingCriteriaList([StopOnTokens()])

# %%
generate_text = transformers.pipeline(
    model=model,
    tokenizer=tokenizer,
    return_full_text=True,  # langchain expects the full text
    task='text-generation',
    # we pass model parameters here too
    stopping_criteria=stopping_criteria,  # without this model rambles during chat
    temperature=0.1,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    max_new_tokens=512,  # max number of tokens to generate in the output
    repetition_penalty=1.1  # without this output begins repeating
)

# %%
res = generate_text("Explain me the difference between Data Lakehouse and Data Warehouse.")
print(res[0]["generated_text"])
# Out:
# Explain me the difference between Data Lakehouse and Data Warehouse. everybody knows that data warehousing is a process of collecting, storing, organizing, and managing large amounts of data from various sources in a single database or data mart for querying and reporting purposes.
#
# A data lakehouse is a centralized repository that stores all of an organization's data, both structured and unstructured, in its native format. Unlike a data warehouse, which is designed to store structured data in a specific schema, a data lakehouse can store any type of data, including semi-structured and unstructured data like text documents, images, videos, and audio files.
#
# Here are some key differences between a data warehouse and a data lakehouse:
#
# 1. Structure: A data warehouse is designed to store structured data in a specific schema, while a data lakehouse stores all types of data, including unstructured data, in its native format.
# 2. Schema: A data warehouse has a predefined schema, which means that the data must be organized into tables with defined columns and relationships. In contrast, a data lakehouse does not have a predefined schema, allowing for more flexibility in how data is stored and queried.
# 3. Data Types: A data warehouse typically stores structured data, such as relational databases, while a data lakehouse can store any type of data, including semi-structured and unstructured data like text documents, images, videos, and audio files.
# 4. Scalability: A data lakehouse is designed to handle large volumes of data and scale horizontally, making it ideal for big data analytics. In contrast, a data warehouse may struggle to handle very large datasets or complex queries.
# 5. Querying: A data warehouse is optimized for querying and reporting on structured data using SQL, while a data lakehouse allows for more flexible querying and analysis of all types of data using distributed computing frameworks like Hadoop or Spark.
# 6. Security: A data warehouse typically has strict security controls in place to protect sensitive data, while a data lakehouse may have less rigorous security controls due to the variety of data stored within it.
# 7. Cost: A data warehouse typically requires significant upfront costs for hardware, software, and personnel, while a data lakehouse can be more cost-effective due to its scalable architecture and use of

# %% [markdown]
# ### Using Langchain

# %%
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=generate_text)

# checking again that everything is working fine
llm(prompt="Explain me the difference between Data Lakehouse and Data Warehouse.")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ' Unterscheidung between data lakehouse and data warehouse is a common topic of discussion in the data engineering community, as both are designed to store large amounts of structured and unstructured data. A data lakehouse is a centralized repository that stores all types of data, including structured, semi-structured, and unstructured data. A data warehouse, on the other hand, is a repository that stores structured data in a specific format, typically optimized for querying and analysis.\n\nHere are some key differences between a data lakehouse and a data warehouse:\n\n1. Data Structure: A data lakehouse stores data in its raw form, without any predefined schema or structure. This allows for greater flexibility in storing and processing different types of data. In contrast, a data warehouse stores data in a structured format, with a defined schema that is optimized for querying and analysis.\n2. Data Types: A data lakehouse can store all types of data, including structured, semi-structured, and unstructured data. A data warehouse typically only stores structured data, such as relational databases.\n3. Scalability: A data lakehouse is designed to handle large volumes of data and scale horizontally, which means it can handle increasing data volumes by adding more nodes to the cluster. A data warehouse, on the other hand, may have limitations in terms of scalability, especially if it is designed for a specific use case or application.\n4. Querying and Analysis: A data warehouse is optimized for querying and analysis, with a focus on fast query performance and adherence to a specific schema. A data lakehouse, on the other hand, provides a flexible platform for storing and processing data, allowing for more complex queries and analysis.\n5. Cost: A data lakehouse can be more cost-effective than a data warehouse, especially for large volumes of unstructured data. This is because a data lakehouse does not require the same level of infrastructure investment as a data warehouse, such as expensive storage systems or specialized hardware.\n6. Governance: A data lakehouse provides better governance capabilities compared to a data warehouse, as it allows for easier management of data access and security. This is because a data lakehouse provides a single, centralized repository for all data, making it easier to enforce data policies and ensure'

# %% [markdown]
# ### Testing data retrieval

# %%
from langchain.document_loaders import TextLoader

loader = TextLoader("data.txt")
documents = loader.load()

#from langchain.document_loaders.csv_loader import CSVLoader
#loader = CSVLoader("data2.csv")

#documents = loader.load()
# from langchain.document_loaders import PyPDFLoader

# loader = PyPDFLoader("file.pdf")
# documents = loader.load_and_split()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
all_splits = text_splitter.split_documents(documents)

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

model_name = "sentence-transformers/all-mpnet-base-v2"
model_kwargs = {"device": "cuda"}

embeddings = HuggingFaceEmbeddings(model_name=model_name, model_kwargs=model_kwargs)

# storing embeddings in the vector store
vectorstore = FAISS.from_documents(all_splits, embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
print(embeddings)
# Out:
# client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# ) model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={'device': 'cuda'} encode_kwargs={} multi_process=False

# %%
from langchain.chains import ConversationalRetrievalChain

chain = ConversationalRetrievalChain.from_llm(llm, vectorstore.as_retriever(), return_source_documents=True)

# %%
chat_history = []

query = "List the contents of the document  "
result = chain({"question": query, "chat_history": chat_history})

print(result['answer'])
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
#  The document contains the following information:
#
# * Stock price forecasts for eight companies (XYZ, ABC, DEF, LMN, PQR, JKL, RST, and UVW)
# * Analyst recommendations for each company (buy, hold, or sell)
# * Median target prices for each company
# * High and low estimates for each company
# * Current consensus ratings among polled investment analysts for each company
#
# Note: The document does not provide any additional information about the companies, such as their financial health, industry trends, or competitive landscape.

# %%
chat_history = [(query, result["answer"])]

query = "What is the Analysts recommendation on ABC Inc ?"
result = chain({"question": query, "chat_history": chat_history})

print(result['answer'])
# Out:
#  Sure! According to the information provided, the median stock price forecast for ABC Inc is $152.80, with a high estimate of $165.40 and a low estimate of $135.20. However, please keep in mind that these are just predictions and actual prices may differ.
